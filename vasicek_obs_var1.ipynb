# %%
# %matplotlib inline
import CompDoobTransform as cdt
import time
from CompDoobTransform import core
import math
import torch
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from CompDoobTransform.utils import normal_logpdf, resampling
plt.style.use('ggplot')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Computing on ' + str(device))
# Out:
# Computing on cpu

# %%
data = pd.read_csv("IR3TED01USQ156N.csv")
data
# Out:
#           DATE  IR3TED01USQ156N
# 0   1999-01-01         4.933333
# 1   1999-04-01         4.993333
# 2   1999-07-01         5.400000
# 3   1999-10-01         6.103333
# 4   2000-01-01         6.063333
# ..         ...              ...
# 85  2020-04-01         0.503333
# 86  2020-07-01         0.200000
# 87  2020-10-01         0.193333
# 88  2021-01-01         0.190000
# 89  2021-04-01         0.166667
#
# [90 rows x 2 columns]

# %%
# tuning parameters 
d = 1
# std_obs = 0.125
std_obs = 1.0
filename = 'vasicek_var_obs_1.pt'

# %%
state = {}

# dimension of state 
state['dim'] = 1

# valeurs tirées du papier des données likelihood estimation
# drift of diffusion 
alpha0 = torch.tensor(0.000563, device = device) 
alpha1 = torch.tensor(-0.00673,device=device)
def drift(x):
    out = torch.zeros(x.shape)    
    out = alpha0 + alpha1 * x
    return out
a = lambda x:  drift(x)# drift
state['drift'] = a

# diffusion coefficient of diffusion

beta0 = torch.tensor(1.66e-05, device = device) 
state['sigma'] = beta0



# time interval
T = torch.tensor(1.0, device = device) 
state['terminal_time'] = T


# time-discretization settings
M = 50 # number of time steps

# %%
# dict for objects relating to observations
obs = {}

# dimension of observation
p = 1
obs['dim'] = p

# observation parameters
var_obs = torch.tensor(std_obs**2, device = device) # variance of observation

# log-observation density
obs_log_density = lambda x, y: normal_logpdf(y, x, var_obs) # terminal condition, returns size (N)
obs['log_density'] = obs_log_density

# %%
# simulate states and observations from model
X0 = torch.tensor(0.083,device= device)
X = X0.clone()
J = 2000
max_index = J*M+1
store_states = torch.zeros(J*M+1, d, device = device)
store_states[0,:] = X    
store_obs = torch.zeros(J*M, d, device = device)
stepsize = torch.tensor(T / M, device = device)
for j in range(J):
    for m in range(M):
        euler = X + stepsize * drift(X)
        W = torch.sqrt(stepsize) * torch.randn(X.shape, device = device)
        X = euler + beta0 * W
        Y = X + torch.sqrt(var_obs) * torch.randn(1, p, device = device)
        index = j*M + m + 1
        store_states[index,:] = X
        store_obs[index-1,:] = Y

# learning standardization means and standard deviations
standardization = {'x_mean': torch.mean(store_states), 
                   'x_std': torch.std(store_states), 
                   'y_mean': torch.mean(store_obs), 
                   'y_std': torch.std(store_obs)}
print(standardization)

# simulate initial states
initial = lambda N: store_states[torch.randint(0, max_index, size = (N,)), :] # function to subsample states
state['initial'] = initial

# simulate observations
observation = lambda N: initial(N) + torch.sqrt(var_obs) * torch.randn(N, p, device = device)
obs['observation'] = observation
# Out:
# <ipython-input-6-1458ac5c568f>:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   stepsize = torch.tensor(T / M, device = device)
# {'x_mean': tensor(0.0835), 'x_std': tensor(0.0002), 'y_mean': tensor(0.0817), 'y_std': tensor(1.0025)}

# %%
plt.plot(store_states.numpy())

# %%
# V0 and Z neural network configuration
V0_net_config = {'layers': [16], 'standardization': standardization}
Z_net_config = {'layers': [d+16], 'standardization': standardization}
net_config = {'V0': V0_net_config, 'Z': Z_net_config}

# optimization configuration (standard training)
I = 2000
optim_config = {'minibatch': 100, 
                'num_obs_per_batch': 10, 
                'num_iterations': I,
                'learning_rate' : 0.01, 
                'initial_required' : True}

# %%
# create model instance
model_static = cdt.core.model(state, obs, M, net_config, device = 'cpu')

# static training
time_start = time.time() 
model_static.train_standard(optim_config)
time_end = time.time()
time_elapsed = time_end - time_start
print("Training time (secs): " + str(time_elapsed))
# Out:
# Optimization iteration: 1 Loss: 2.3257896900177
# Optimization iteration: 50 Loss: 0.15689608454704285
# Optimization iteration: 100 Loss: 0.022825364023447037
# Optimization iteration: 150 Loss: 0.01633267290890217
# Optimization iteration: 200 Loss: 0.028842590749263763
# Optimization iteration: 250 Loss: 0.021632103249430656
# Optimization iteration: 300 Loss: 0.11235347390174866
# Optimization iteration: 350 Loss: 0.005064900033175945
# Optimization iteration: 400 Loss: 0.006446543615311384
# Optimization iteration: 450 Loss: 0.004283659625798464
# Optimization iteration: 500 Loss: 0.0075262077152729034
# Optimization iteration: 550 Loss: 0.0024637177120894194
# Optimization iteration: 600 Loss: 0.0066935778595507145
# Optimization iteration: 650 Loss: 0.037169601768255234
# Optimization iteration: 700 Loss: 0.004534916952252388
# Optimization iteration: 750 Loss: 0.000896075158379972
# Optimization iteration: 800 Loss: 0.0008357717888429761
# Optimization iteration: 850 Loss: 0.7713221311569214
# Optimization iteration: 900 Loss: 0.0016412039985880256
# Optimization iteration: 950 Loss: 0.0009988897945731878
# Optimization iteration: 1000 Loss: 0.0039461394771933556
# Optimization iteration: 1050 Loss: 0.0007888539112173021
# Optimization iteration: 1100 Loss: 0.0017185165779665112
# Optimization iteration: 1150 Loss: 0.027300864458084106
# Optimization iteration: 1200 Loss: 0.00037953161518089473
# Optimization iteration: 1250 Loss: 0.0005022395052947104
# Optimization iteration: 1300 Loss: 0.00047222827561199665
# Optimization iteration: 1350 Loss: 0.00023419978970196098
# Optimization iteration: 1400 Loss: 0.0003433723468333483
# Optimization iteration: 1450 Loss: 0.0003799490805249661
# Optimization iteration: 1500 Loss: 0.0002409247390460223
# Optimization iteration: 1550 Loss: 0.0006104018539190292
# Optimization iteration: 1600 Loss: 0.000948749715462327
# Optimization iteration: 1650 Loss: 0.0007635169313289225
# Optimization iteration: 1700 Loss: 0.00018842905410565436
# Optimization iteration: 1750 Loss: 0.02594374679028988
# Optimization iteration: 1800 Loss: 0.00014137431571725756
# Optimization iteration: 1850 Loss: 0.0023549862671643496
# Optimization iteration: 1900 Loss: 0.00016415680875070393
# Optimization iteration: 1950 Loss: 0.0002453680499456823
# Optimization iteration: 2000 Loss: 0.00010096588812302798
# Training time (secs): 106.88904786109924

# %%
# create model instance
model = cdt.core.model(state, obs, M, net_config, device = 'cpu')

# iterative training
time_start = time.time() 
model.train_iterative(optim_config)
time_end = time.time()
time_elapsed = time_end - time_start
print("Training time (secs): " + str(time_elapsed))
# Out:
# Optimization iteration: 1 Loss: 4.277419090270996
# Optimization iteration: 50 Loss: 0.19953833520412445
# Optimization iteration: 100 Loss: 0.028147434815764427
# Optimization iteration: 150 Loss: 0.06276707351207733
# Optimization iteration: 200 Loss: 0.025121986865997314
# Optimization iteration: 250 Loss: 0.010379615239799023
# Optimization iteration: 300 Loss: 0.013252443633973598
# Optimization iteration: 350 Loss: 0.05225026607513428
# Optimization iteration: 400 Loss: 0.006073202006518841
# Optimization iteration: 450 Loss: 0.013050328940153122
# Optimization iteration: 500 Loss: 0.002696356736123562
# Optimization iteration: 550 Loss: 0.004078580532222986
# Optimization iteration: 600 Loss: 0.002599369967356324
# Optimization iteration: 650 Loss: 0.0016674748621881008
# Optimization iteration: 700 Loss: 0.0054516964592039585
# Optimization iteration: 750 Loss: 0.0005546186002902687
# Optimization iteration: 800 Loss: 0.0009605030063539743
# Optimization iteration: 850 Loss: 0.003047744743525982
# Optimization iteration: 900 Loss: 0.0008167782798409462
# Optimization iteration: 950 Loss: 0.006839820649474859
# Optimization iteration: 1000 Loss: 0.0035875821486115456
# Optimization iteration: 1050 Loss: 0.0017521106638014317
# Optimization iteration: 1100 Loss: 0.0014389901189133525
# Optimization iteration: 1150 Loss: 0.00020682704052887857
# Optimization iteration: 1200 Loss: 0.0065277027897536755
# Optimization iteration: 1250 Loss: 0.0002461582189425826
# Optimization iteration: 1300 Loss: 0.022091807797551155
# Optimization iteration: 1350 Loss: 0.0013727531768381596
# Optimization iteration: 1400 Loss: 0.0015602648491039872
# Optimization iteration: 1450 Loss: 0.0011250674724578857
# Optimization iteration: 1500 Loss: 0.00027849109028466046
# Optimization iteration: 1550 Loss: 0.001360247377306223
# Optimization iteration: 1600 Loss: 0.002967190695926547
# Optimization iteration: 1650 Loss: 0.0004279366694390774
# Optimization iteration: 1700 Loss: 0.000731301901396364
# Optimization iteration: 1750 Loss: 0.003594357753172517
# Optimization iteration: 1800 Loss: 0.001629984355531633
# Optimization iteration: 1850 Loss: 0.00012110950046917424
# Optimization iteration: 1900 Loss: 0.0066168420016765594
# Optimization iteration: 1950 Loss: 0.0021746049169451
# Optimization iteration: 2000 Loss: 0.0010816871654242277
# Training time (secs): 124.59468197822571

# %%
# repeat particle filters
multiplier = 1.0
num_obs = [100, 200, 400, 800]
len_num_obs = len(num_obs)
num_particles = [2**6, 2**7, 2**8, 2**9]
R = 20 # number of repeats


APFF = {'ess' : torch.zeros(len_num_obs, R), 'log_estimate' : torch.zeros(len_num_obs, R)}
BPF = {'ess' : torch.zeros(len_num_obs, R), 'log_estimate' : torch.zeros(len_num_obs, R)}

# %%
for i in range(len_num_obs):
    # number of observations
    K = num_obs[i]

    # number of particles
    N = num_particles[i]

    # simulate latent process and observations
    X0 = torch.ones(1,d)
    X = torch.zeros(K+1, d)
    X[0,:] = X0.clone()
    Y = torch.zeros(K, p)
    for k in range(K):
        X[k+1,:] = model.simulate_diffusion(X[k,:].reshape((1,d)))
        Y[k,:] = X[k+1,:] + multiplier * torch.sqrt(var_obs) * torch.randn(1,p)

    for r in range(R):
        # run particle filters
        BPF_output = model.run_BPF(X0.repeat((N,1)), Y, N)
        APFF_output = model_static.run_APF(X0.repeat((N,1)), Y, N)

        # save average ESS%
        BPF_ESS = torch.mean(BPF_output['ess'] * 100 / N)
        APFF_ESS = torch.mean(APFF_output['ess'] * 100 / N)
        BPF['ess'][i,r] = BPF_ESS
        APFF['ess'][i,r] = APFF_ESS

        # save log-likelihood estimates
        BPF_log_estimate = BPF_output['log_norm_const'][-1]
        APFF_log_estimate = APFF_output['log_norm_const'][-1]
        BPF['log_estimate'][i,r] = BPF_log_estimate
        APFF['log_estimate'][i,r] = APFF_log_estimate

        # print output
        print('No. of observations: ' + str(K) + ' Repeat: ' + str(r)) 
        print('BPF ESS%: ' + str(BPF_ESS))
        print('APFF ESS%: ' + str(APFF_ESS)) 
        print('BPF log-estimate: ' + str(BPF_log_estimate))
        print('APFF log-estimate: ' + str(APFF_log_estimate))

# save results
results = {'BPF' : BPF, 'APFF' : APFF}
torch.save(results, filename)
# Out:
# No. of observations: 100 Repeat: 0
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(2.8742)
# BPF log-estimate: tensor(-145.6683)
# APFF log-estimate: tensor(-21075.9121)
# No. of observations: 100 Repeat: 1
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(2.8792)
# BPF log-estimate: tensor(-145.6679)
# APFF log-estimate: tensor(-21153.0430)
# No. of observations: 100 Repeat: 2
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(2.8493)
# BPF log-estimate: tensor(-145.6681)
# APFF log-estimate: tensor(-20884.7520)
# No. of observations: 100 Repeat: 3
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(2.8450)
# BPF log-estimate: tensor(-145.6681)
# APFF log-estimate: tensor(-20923.2656)
# No. of observations: 100 Repeat: 4
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(2.8996)
# BPF log-estimate: tensor(-145.6684)
# APFF log-estimate: tensor(-21028.2402)
# No. of observations: 100 Repeat: 5
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(2.6625)
# BPF log-estimate: tensor(-145.6678)
# APFF log-estimate: tensor(-20824.4023)
# No. of observations: 100 Repeat: 6
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(2.9512)
# BPF log-estimate: tensor(-145.6680)
# APFF log-estimate: tensor(-21131.2402)
# No. of observations: 100 Repeat: 7
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(2.7829)
# BPF log-estimate: tensor(-145.6679)
# APFF log-estimate: tensor(-20915.3828)
# No. of observations: 100 Repeat: 8
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(2.8362)
# BPF log-estimate: tensor(-145.6677)
# APFF log-estimate: tensor(-20943.7090)
# No. of observations: 100 Repeat: 9
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(2.8989)
# BPF log-estimate: tensor(-145.6680)
# APFF log-estimate: tensor(-20979.7188)
# No. of observations: 100 Repeat: 10
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(3.0291)
# BPF log-estimate: tensor(-145.6679)
# APFF log-estimate: tensor(-20959.5430)
# No. of observations: 100 Repeat: 11
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(2.7750)
# BPF log-estimate: tensor(-145.6682)
# APFF log-estimate: tensor(-20857.9043)
# No. of observations: 100 Repeat: 12
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(2.8597)
# BPF log-estimate: tensor(-145.6681)
# APFF log-estimate: tensor(-20952.3750)
# No. of observations: 100 Repeat: 13
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(2.8107)
# BPF log-estimate: tensor(-145.6678)
# APFF log-estimate: tensor(-20836.6895)
# No. of observations: 100 Repeat: 14
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(2.9241)
# BPF log-estimate: tensor(-145.6677)
# APFF log-estimate: tensor(-20973.8984)
# No. of observations: 100 Repeat: 15
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(2.8773)
# BPF log-estimate: tensor(-145.6681)
# APFF log-estimate: tensor(-20923.3848)
# No. of observations: 100 Repeat: 16
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(2.7659)
# BPF log-estimate: tensor(-145.6679)
# APFF log-estimate: tensor(-20906.9629)
# No. of observations: 100 Repeat: 17
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(2.9592)
# BPF log-estimate: tensor(-145.6679)
# APFF log-estimate: tensor(-20967.6543)
# No. of observations: 100 Repeat: 18
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(2.8721)
# BPF log-estimate: tensor(-145.6684)
# APFF log-estimate: tensor(-20917.4883)
# No. of observations: 100 Repeat: 19
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(2.8579)
# BPF log-estimate: tensor(-145.6681)
# APFF log-estimate: tensor(-20935.3652)
# No. of observations: 200 Repeat: 0
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5940)
# BPF log-estimate: tensor(-284.6642)
# APFF log-estimate: tensor(-25349.4844)
# No. of observations: 200 Repeat: 1
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5768)
# BPF log-estimate: tensor(-284.6624)
# APFF log-estimate: tensor(-25050.7129)
# No. of observations: 200 Repeat: 2
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5675)
# BPF log-estimate: tensor(-284.6634)
# APFF log-estimate: tensor(-25118.6250)
# No. of observations: 200 Repeat: 3
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5012)
# BPF log-estimate: tensor(-284.6642)
# APFF log-estimate: tensor(-25055.7012)
# No. of observations: 200 Repeat: 4
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5743)
# BPF log-estimate: tensor(-284.6616)
# APFF log-estimate: tensor(-25282.4316)
# No. of observations: 200 Repeat: 5
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.6012)
# BPF log-estimate: tensor(-284.6648)
# APFF log-estimate: tensor(-25124.8828)
# No. of observations: 200 Repeat: 6
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5543)
# BPF log-estimate: tensor(-284.6647)
# APFF log-estimate: tensor(-25113.8906)
# No. of observations: 200 Repeat: 7
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5294)
# BPF log-estimate: tensor(-284.6624)
# APFF log-estimate: tensor(-25199.7598)
# No. of observations: 200 Repeat: 8
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5567)
# BPF log-estimate: tensor(-284.6627)
# APFF log-estimate: tensor(-25163.7559)
# No. of observations: 200 Repeat: 9
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5416)
# BPF log-estimate: tensor(-284.6633)
# APFF log-estimate: tensor(-25174.5488)
# No. of observations: 200 Repeat: 10
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5383)
# BPF log-estimate: tensor(-284.6646)
# APFF log-estimate: tensor(-25199.8809)
# No. of observations: 200 Repeat: 11
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5565)
# BPF log-estimate: tensor(-284.6618)
# APFF log-estimate: tensor(-25218.2832)
# No. of observations: 200 Repeat: 12
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5168)
# BPF log-estimate: tensor(-284.6642)
# APFF log-estimate: tensor(-25260.7266)
# No. of observations: 200 Repeat: 13
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5378)
# BPF log-estimate: tensor(-284.6626)
# APFF log-estimate: tensor(-25263.2070)
# No. of observations: 200 Repeat: 14
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5306)
# BPF log-estimate: tensor(-284.6640)
# APFF log-estimate: tensor(-25102.2617)
# No. of observations: 200 Repeat: 15
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5710)
# BPF log-estimate: tensor(-284.6629)
# APFF log-estimate: tensor(-25074.6406)
# No. of observations: 200 Repeat: 16
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5540)
# BPF log-estimate: tensor(-284.6640)
# APFF log-estimate: tensor(-25051.7246)
# No. of observations: 200 Repeat: 17
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5484)
# BPF log-estimate: tensor(-284.6630)
# APFF log-estimate: tensor(-25229.8359)
# No. of observations: 200 Repeat: 18
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5517)
# BPF log-estimate: tensor(-284.6612)
# APFF log-estimate: tensor(-25019.3594)
# No. of observations: 200 Repeat: 19
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.6252)
# BPF log-estimate: tensor(-284.6641)
# APFF log-estimate: tensor(-25335.6758)
# No. of observations: 400 Repeat: 0
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.4551)
# BPF log-estimate: tensor(-568.2010)
# APFF log-estimate: tensor(-25418.3301)
# No. of observations: 400 Repeat: 1
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.6220)
# BPF log-estimate: tensor(-568.2037)
# APFF log-estimate: tensor(-25575.0410)
# No. of observations: 400 Repeat: 2
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.4937)
# BPF log-estimate: tensor(-568.2034)
# APFF log-estimate: tensor(-25581.7812)
# No. of observations: 400 Repeat: 3
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5468)
# BPF log-estimate: tensor(-568.2032)
# APFF log-estimate: tensor(-25618.9219)
# No. of observations: 400 Repeat: 4
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5816)
# BPF log-estimate: tensor(-568.2031)
# APFF log-estimate: tensor(-25509.3008)
# No. of observations: 400 Repeat: 5
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.4852)
# BPF log-estimate: tensor(-568.2050)
# APFF log-estimate: tensor(-25426.5527)
# No. of observations: 400 Repeat: 6
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5526)
# BPF log-estimate: tensor(-568.2026)
# APFF log-estimate: tensor(-25694.9805)
# No. of observations: 400 Repeat: 7
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5545)
# BPF log-estimate: tensor(-568.2028)
# APFF log-estimate: tensor(-25823.1328)
# No. of observations: 400 Repeat: 8
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.6140)
# BPF log-estimate: tensor(-568.2026)
# APFF log-estimate: tensor(-25758.5020)
# No. of observations: 400 Repeat: 9
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.6458)
# BPF log-estimate: tensor(-568.2015)
# APFF log-estimate: tensor(-25563.1836)
# No. of observations: 400 Repeat: 10
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.6091)
# BPF log-estimate: tensor(-568.2020)
# APFF log-estimate: tensor(-25682.5137)
# No. of observations: 400 Repeat: 11
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.6740)
# BPF log-estimate: tensor(-568.2036)
# APFF log-estimate: tensor(-25675.1172)
# No. of observations: 400 Repeat: 12
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5920)
# BPF log-estimate: tensor(-568.2017)
# APFF log-estimate: tensor(-25434.3027)
# No. of observations: 400 Repeat: 13
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.6037)
# BPF log-estimate: tensor(-568.2003)
# APFF log-estimate: tensor(-25279.3340)
# No. of observations: 400 Repeat: 14
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5476)
# BPF log-estimate: tensor(-568.2007)
# APFF log-estimate: tensor(-25738.0645)
# No. of observations: 400 Repeat: 15
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5519)
# BPF log-estimate: tensor(-568.2023)
# APFF log-estimate: tensor(-25649.1660)
# No. of observations: 400 Repeat: 16
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.6002)
# BPF log-estimate: tensor(-568.2015)
# APFF log-estimate: tensor(-25738.9746)
# No. of observations: 400 Repeat: 17
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.4558)
# BPF log-estimate: tensor(-568.2012)
# APFF log-estimate: tensor(-25692.2500)
# No. of observations: 400 Repeat: 18
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.6157)
# BPF log-estimate: tensor(-568.2040)
# APFF log-estimate: tensor(-25545.8555)
# No. of observations: 400 Repeat: 19
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(1.5607)
# BPF log-estimate: tensor(-568.2049)
# APFF log-estimate: tensor(-25546.2129)
# No. of observations: 800 Repeat: 0
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(34.0192)
# BPF log-estimate: tensor(-1153.6846)
# APFF log-estimate: tensor(-25598.0078)
# No. of observations: 800 Repeat: 1
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(33.8823)
# BPF log-estimate: tensor(-1153.6866)
# APFF log-estimate: tensor(-25453.2402)
# No. of observations: 800 Repeat: 2
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(33.6742)
# BPF log-estimate: tensor(-1153.6870)
# APFF log-estimate: tensor(-25505.8320)
# No. of observations: 800 Repeat: 3
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(33.8651)
# BPF log-estimate: tensor(-1153.6857)
# APFF log-estimate: tensor(-25377.1836)
# No. of observations: 800 Repeat: 4
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(33.8623)
# BPF log-estimate: tensor(-1153.6877)
# APFF log-estimate: tensor(-25687.0352)
# No. of observations: 800 Repeat: 5
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(33.8629)
# BPF log-estimate: tensor(-1153.6876)
# APFF log-estimate: tensor(-25532.3145)
# No. of observations: 800 Repeat: 6
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(33.8965)
# BPF log-estimate: tensor(-1153.6855)
# APFF log-estimate: tensor(-25566.4785)
# No. of observations: 800 Repeat: 7
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(33.7999)
# BPF log-estimate: tensor(-1153.6868)
# APFF log-estimate: tensor(-25402.4707)
# No. of observations: 800 Repeat: 8
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(34.0362)
# BPF log-estimate: tensor(-1153.6895)
# APFF log-estimate: tensor(-25403.2285)
# No. of observations: 800 Repeat: 9
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(33.9435)
# BPF log-estimate: tensor(-1153.6879)
# APFF log-estimate: tensor(-25362.9707)
# No. of observations: 800 Repeat: 10
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(33.9294)
# BPF log-estimate: tensor(-1153.6857)
# APFF log-estimate: tensor(-25535.7402)
# No. of observations: 800 Repeat: 11
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(33.8728)
# BPF log-estimate: tensor(-1153.6884)
# APFF log-estimate: tensor(-25666.4238)
# No. of observations: 800 Repeat: 12
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(33.8496)
# BPF log-estimate: tensor(-1153.6842)
# APFF log-estimate: tensor(-25347.5977)
# No. of observations: 800 Repeat: 13
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(33.8942)
# BPF log-estimate: tensor(-1153.6863)
# APFF log-estimate: tensor(-25372.6387)
# No. of observations: 800 Repeat: 14
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(33.9148)
# BPF log-estimate: tensor(-1153.6875)
# APFF log-estimate: tensor(-25305.1816)
# No. of observations: 800 Repeat: 15
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(33.9176)
# BPF log-estimate: tensor(-1153.6865)
# APFF log-estimate: tensor(-25420.5371)
# No. of observations: 800 Repeat: 16
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(33.9910)
# BPF log-estimate: tensor(-1153.6866)
# APFF log-estimate: tensor(-25604.4707)
# No. of observations: 800 Repeat: 17
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(33.8934)
# BPF log-estimate: tensor(-1153.6874)
# APFF log-estimate: tensor(-25471.6230)
# No. of observations: 800 Repeat: 18
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(33.9300)
# BPF log-estimate: tensor(-1153.6853)
# APFF log-estimate: tensor(-25423.9199)
# No. of observations: 800 Repeat: 19
# BPF ESS%: tensor(100.)
# APFF ESS%: tensor(33.8720)
# BPF log-estimate: tensor(-1153.6898)
# APFF log-estimate: tensor(-25618.5254)

# %%
BPF["ess"]
# Out:
# tensor([[100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100.,
#          100., 100., 100., 100., 100., 100., 100., 100.],
#         [100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100.,
#          100., 100., 100., 100., 100., 100., 100., 100.],
#         [100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100.,
#          100., 100., 100., 100., 100., 100., 100., 100.],
#         [100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100.,
#          100., 100., 100., 100., 100., 100., 100., 100.]])

# %%
plt.plot(num_obs,APFF["log_estimate"].var(1))
plt.plot(num_obs,BPF["log_estimate"].var(1))
plt.legend(["FA-APF","BPF"])
plt.show()
